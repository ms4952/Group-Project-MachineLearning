# %% [markdown]
# # Building a song recommender to users using collaborative filtering and KNN
#
#
# #Import pandas

# %%
import pandas as pd

# %% [markdown]
# #Load music data

# %%
usage_data = pd.read_table('https://static.turi.com/datasets/millionsong/10000.txt', header = None)
usage_data.rename(columns={0:'user_id', 1:'song_id', 2:'listen_count'}, inplace = True)

song_data = pd.read_csv('https://static.turi.com/datasets/millionsong/song_data.csv')
song_data.drop_duplicates(['song_id'])

song_data = pd.merge(usage_data, song_data, on="song_id", how="left")
song_data['song'] = song_data['artist_name'].map(str) + " - " + song_data['title']

song_data = song_data.drop(['release','year'],axis=1)

song_data
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# ...                                           ...                 ...
# 2086941  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJEYPO12AAA8C6B0E
# 2086942  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJJYDE12AF729FC16
# 2086943  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJKQSF12A6D4F5EE9
# 2086944  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJUXGA12AC961885C
# 2086945  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJYOLS12A8C13C06F
#
#          listen_count                           title  \
# 0                   1                        The Cove
# 1                   2                 Entre Dos Aguas
# 2                   1                        Stronger
# 3                   1                        Stronger
# 4                   1                  Constellations
# ...               ...                             ...
# 2086941             2       Ignorance (Album Version)
# 2086942             4          Two Is Better Than One
# 2086943             3  What I've Done (Album Version)
# 2086944             1                              Up
# 2086945             1      Soil_ Soil (Album Version)
#
#                                     artist_name  \
# 0                                  Jack Johnson
# 1                                 Paco De Lucia
# 2                                    Kanye West
# 3                                    Kanye West
# 4                                  Jack Johnson
# ...                                         ...
# 2086941                                Paramore
# 2086942  Boys Like Girls featuring Taylor Swift
# 2086943                             Linkin Park
# 2086944                           Justin Bieber
# 2086945                          Tegan And Sara
#
#                                                       song
# 0                                  Jack Johnson - The Cove
# 1                          Paco De Lucia - Entre Dos Aguas
# 2                                    Kanye West - Stronger
# 3                                    Kanye West - Stronger
# 4                            Jack Johnson - Constellations
# ...                                                    ...
# 2086941               Paramore - Ignorance (Album Version)
# 2086942  Boys Like Girls featuring Taylor Swift - Two I...
# 2086943       Linkin Park - What I've Done (Album Version)
# 2086944                                 Justin Bieber - Up
# 2086945        Tegan And Sara - Soil_ Soil (Album Version)
#
# [2086946 rows x 6 columns]

# %% [markdown]
# # Explore data
#
# Music data shows how many times a user listened to a song, as well as the details of the song.

# %%
song_data.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
#
#              title    artist_name                             song
# 0         The Cove   Jack Johnson          Jack Johnson - The Cove
# 1  Entre Dos Aguas  Paco De Lucia  Paco De Lucia - Entre Dos Aguas
# 2         Stronger     Kanye West            Kanye West - Stronger
# 3         Stronger     Kanye West            Kanye West - Stronger
# 4   Constellations   Jack Johnson    Jack Johnson - Constellations

# %% [markdown]
# ##Showing the most popular songs in the dataset

# %%
song_data['song'].value_counts()
# Out:
# Harmonia - Sehr kosmisch                                   8277
# Kings Of Leon - Use Somebody                               7952
# Björk - Undo                                               7032
# Florence + The Machine - Dog Days Are Over (Radio Edit)    6949
# Dwight Yoakam - You're The One                             6412
#                                                            ...
# Three Days Grace - Scared                                    51
# Ricardo Arjona - Historia Del Portero                        51
# Amparanoia - Don´t Leave Me Now                              50
# Juanes - No Creo En El Jamas                                 48
# Ladytron - Ghosts (Toxic Avenger Mix)                        48
# Name: song, Length: 9982, dtype: int64

# %%
# Out:
# 2086946

# %%
s=song_data['song'].value_counts().nlargest(10)
print("songs to recommend based on popularity\n",s)
# Out:
# songs to recommend based on popularity
#
#  Harmonia - Sehr kosmisch                                                                                                                        8277
# Kings Of Leon - Use Somebody                                                                                                                    7952
# Björk - Undo                                                                                                                                    7032
# Florence + The Machine - Dog Days Are Over (Radio Edit)                                                                                         6949
# Dwight Yoakam - You're The One                                                                                                                  6412
# Kings Of Leon - Revelry                                                                                                                         6145
# OneRepublic - Secrets                                                                                                                           5841
# Coldplay - Yellow                                                                                                                               5658
# Justin Bieber - Somebody To Love                                                                                                                5546
# Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner - Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)    5385
# Name: song, dtype: int64

# %% [markdown]
# ##Count number of unique users in the dataset

# %%
users = song_data['user_id'].unique()

# %%
len(users)
# Out:
# 76353

# %% [markdown]
# # Create a song recommender

# %% [markdown]
# # Using Collaborative Filtering

# %% [markdown]
# Create a matrix with number of users * number of songs shape.
# Each entry in the array represent the number of times songs listened by a particular user

# %%
song = song_data.drop_duplicates(['user_id','song','title','artist_name'])
song = song.reset_index(drop=True)

# %%
pop_songs=song
#print(pop_songs.head())
pop_songs=pop_songs.sort_values(by='song',ascending=False)
#pop_songs = pop_songs.filter(['listen_count','song_id'], axis=1) 
#pop_songs= pop_songs.drop_duplicates(subset='song_id', keep="first")

result = pop_songs.head(10)
print(result)
# Out:
#                                           user_id             song_id  \
# 1116748  4f6924c33baef717acc98a07face38d20918e1c0  SOJJJJR12A6D4F9584
# 101692   b1eac465eb6838e2a2b86413e93107108bc1bfba  SOJJJJR12A6D4F9584
# 358575   798713860923b23c991821cb53e4b1a16e80fe11  SOJJJJR12A6D4F9584
# 1232284  be178d1747723e807a35d0a817f710d7552de337  SOJJJJR12A6D4F9584
# 1834000  23d6305eb466f7fff2bf840fae90f2bdf6b01151  SOJJJJR12A6D4F9584
# 697192   19f1d7c18a777747c7865e8e980c664f63bae687  SOJJJJR12A6D4F9584
# 1281140  96dfd6436c2416458cf5a95e16dd2726581a6df9  SOJJJJR12A6D4F9584
# 590834   3f27ddaaea5347363f65ea5ee32165579167f1f1  SOJJJJR12A6D4F9584
# 1924613  30cdb9e4f95eaea2be1306fc0f557a647a5f8885  SOJJJJR12A6D4F9584
# 1447347  66f6867503d85683367f6cf8c71f468f5ca23ed3  SOJJJJR12A6D4F9584
#
#          listen_count                                              title  \
# 1116748             1  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 101692              8  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 358575              1  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 1232284             4  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 1834000             1  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 697192              1  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 1281140             1  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 590834              1  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 1924613             2  Lose My Soul feat. Kirk Franklin & Mandisa / A...
# 1447347            15  Lose My Soul feat. Kirk Franklin & Mandisa / A...
#
#         artist_name                                               song
# 1116748     tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 101692      tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 358575      tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 1232284     tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 1834000     tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 697192      tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 1281140     tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 590834      tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 1924613     tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...
# 1447347     tobyMac  tobyMac - Lose My Soul feat. Kirk Franklin & M...

# %% [markdown]
# Use only 50000 items in song_data (jupyter notebook has memory limitatons)

# %%
song=song.iloc[0:50000,]
song.shape
# Out:
# (50000, 6)

# %%
song.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title    artist_name                             song
# 0         The Cove   Jack Johnson          Jack Johnson - The Cove
# 1  Entre Dos Aguas  Paco De Lucia  Paco De Lucia - Entre Dos Aguas
# 2         Stronger     Kanye West            Kanye West - Stronger
# 3   Constellations   Jack Johnson    Jack Johnson - Constellations
# 4     Learn To Fly   Foo Fighters      Foo Fighters - Learn To Fly

# %% [markdown]
# This is going to be the filtering table

# %%
song_pivot=song.pivot_table(index='user_id',columns='song_id',values='listen_count')

# %%
song_pivot.shape
# Out:
# (1869, 9351)

# %%
song_pivot=song_pivot.fillna(0)

# %%
song_pivot[song_pivot.SOBYHAJ12A6701BF1D==1]
# Out:
# song_id                                   SOAAAGQ12A8C1420C8  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAACPJ12A81C21360  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAAEJI12AB0188AB5  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAAFAC12A67ADF7EB  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 1.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAAFYH12A8C13717A  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAAKPM12A58A77210  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAAOYI12AB01831CE  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAAROC12A6D4FA420  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAARXR12A8C133D15  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOAATHE12A8C13ADD6  ...  \
# user_id                                                       ...
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0  ...
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0  ...
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0  ...
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0  ...
# 572da9d6331782b8c48924968f0778a331170c20                 0.0  ...
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0  ...
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0  ...
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0  ...
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0  ...
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0  ...
# d33cda518d1d2191ed75b4560da852771893958f                 0.0  ...
#
# song_id                                   SOZZIOH12A67ADE300  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZKPR12A6D4F8147  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZLTY12A67AE0AD0  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZLZN12A8AE48D6D  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZRHE12A6702165F  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZTCU12AB0182C58  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZTNF12A8C139916  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZVWB12AB0189C30  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZWZV12A67AE140F  \
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# song_id                                   SOZZYAO12A6701FF36
# user_id
# 1645b689f873529ab85e3b72742be44813e82bd3                 0.0
# 2a8a8f48fd4eb5ca4b64874162df4fdf584d89c4                 0.0
# 3f73f44560e822344b0fb7c6b463869743eb9860                 0.0
# 41ef7daf3d368922c9676d3f90c8fe931cac1d35                 0.0
# 572da9d6331782b8c48924968f0778a331170c20                 0.0
# 6f8453b0d9d2199f98c1992995a8445ad6837fd8                 0.0
# 7a4b8e7d2905d13422418b4f48cc85100892e013                 0.0
# b2cbcf5ea3c6ea3ee41ceac0ef247c2b1ddedbdc                 0.0
# b80344d063b5ccb3212f76538f3d9e43d87dca9e                 0.0
# c24ec42f0e449ff39a95a01f0795f833b898f71b                 0.0
# d33cda518d1d2191ed75b4560da852771893958f                 0.0
#
# [11 rows x 9351 columns]

# %% [markdown]
# # Train a Knn model using pivot_table

# %%
from sklearn.neighbors import NearestNeighbors
knn=NearestNeighbors(n_neighbors=10,metric='cosine')
Model=knn.fit(song_pivot)

# %%
song_pivot[song_pivot.index == 1]
# Out:
# Empty DataFrame
# Columns: [SOAAAGQ12A8C1420C8, SOAACPJ12A81C21360, SOAAEJI12AB0188AB5, SOAAFAC12A67ADF7EB, SOAAFYH12A8C13717A, SOAAKPM12A58A77210, SOAAOYI12AB01831CE, SOAAROC12A6D4FA420, SOAARXR12A8C133D15, SOAATHE12A8C13ADD6, SOAATLI12A8C13E319, SOAAUKC12AB017F868, SOAAVUV12AB0186646, SOAAWEE12A6D4FBEC8, SOABGOB12A6701D1FA, SOABHNP12A8AE46E82, SOABHYV12A6D4F6D0F, SOABJBU12A8C13F63F, SOABJTC12A58A7DE0E, SOABNLP12A6D4F87F4, SOABNPW12A6D4FC9B5, SOABOHM12AB018509C, SOABOXV12AC3DF82F7, SOABPQU12A58A78441, SOABQTG12A6701F3DB, SOABRAB12A6D4F7AAF, SOABTTR12A6D4FC2EB, SOABXNE12A8C13B818, SOACBLB12AB01871C7, SOACDMD12A67AD8332, SOACIPG12A8AE47E1C, SOACKIA12A6D4F73D7, SOACNQJ12A8C13B09E, SOACPBY12A8C13FEF9, SOACPSU12A81C231EF, SOACRBY12AB017C757, SOACXET12AB01852E3, SOACYKU12A5891CC64, SOACYUL12A6D4F9C79, SOADCFY12A6310E353, SOADELR12AB0181A6D, SOADFMR12A6701FB5F, SOADISH12AB018DFAC, SOADJGO12AB0185D5B, SOADJQJ12A8C141D38, SOADKJJ12A67ADB371, SOADKOB12AB017DB36, SOADMBB12AB017C0F1, SOADMKP12A8C13BAA4, SOADMTV12A6701FA3F, SOADOQJ12A8AE45C7E, SOADOVQ12AB01797EB, SOADOWZ12AB01887EF, SOADQMO12A8C136FF9, SOADQPP12A67020C82, SOADSKA12AB01860FA, SOADVUP12AB0185246, SOADZWN12A8C136C60, SOAECLL12A58A7E668, SOAEEMQ12A8C142D36, SOAEEXF12A8C13E49F, SOAEGIH12A6D4F8B51, SOAEHEX12A8C13EFA4, SOAEIDM12A6D4F8463, SOAEIFW12A8C1391E4, SOAEJAC12A58A7C609, SOAEJNB12A8C13F64D, SOAEJVN12A8C14346F, SOAEKIE12A6701FEAD, SOAEPVF12A8C13722D, SOAESGK12A8C138488, SOAETMP12A8C140E7F, SOAEUPY12A58A79B84, SOAEUYZ12AF72A6379, SOAEYBP12AB0184573, SOAEYCM12A58A7CDDE, SOAFAXA12A58A7BB11, SOAFBKA12A58A7ACCF, SOAFELG12A8C1323D5, SOAFHIF12AB0184446, SOAFKAJ12AB0181B91, SOAFLLJ12A8C133C8D, SOAFPPR12A8AE46454, SOAFPSO12AF72A4521, SOAFQGA12A8C1367FA, SOAFQMR12A6D4F755A, SOAFTRR12AF72A8D4D, SOAFVWW12A58A7E1CB, SOAGFFD12AC909761F, SOAGGLN12AB018AC9B, SOAGIAY12AB0183D8F, SOAGKBO12AB0186943, SOAGLRX12A6D4F822B, SOAGMLZ12A8C13B808, SOAGNRU12A58A7AC5C, SOAGRCT12AB017B552, SOAGSYE12A58A7A5A7, SOAGWPY12AB018CD74, SOAHEEC12A6BD4DAA4, SOAHJQY12AB018534B, ...]
# Index: []
#
# [0 rows x 9351 columns]

# %% [markdown]
# # Predict neighbors for a particular user

# %%
user = song_pivot.iloc[1,]
user
# Out:
# song_id
# SOAAAGQ12A8C1420C8    0.0
# SOAACPJ12A81C21360    0.0
# SOAAEJI12AB0188AB5    0.0
# SOAAFAC12A67ADF7EB    0.0
# SOAAFYH12A8C13717A    0.0
#                      ...
# SOZZTCU12AB0182C58    0.0
# SOZZTNF12A8C139916    0.0
# SOZZVWB12AB0189C30    0.0
# SOZZWZV12A67AE140F    0.0
# SOZZYAO12A6701FF36    0.0
# Name: 000ebc858861aca26bac9b49f650ed424cf882fc, Length: 9351, dtype: float64

# %%
distances, indices = Model.kneighbors([user])
distances, indices
# Out:
# (array([[1.22124533e-15, 8.92509706e-01, 8.97647465e-01, 9.08646800e-01,
#          9.09924530e-01, 9.10371558e-01, 9.28041741e-01, 9.33108996e-01,
#          9.34218178e-01, 9.34245232e-01]]),
#  array([[   1,  217, 1506,  546,  473, 1256,  786,   80, 1159,  687]]))

# %% [markdown]
# The indices contains only the index values of users from the user table. It doesnt show user_id.
# We've to find out user_id of neighbors

# %%
neighbors=[]
for item in indices[0][1:]:
    neighbors.append(song[song.index == item].user_id.values[0])
neighbors
# Out:
# ['17aa9f6dbdf753831da8f38c71b66b64373de613',
#  '484b69dd013df1ec0cfd504886d4f647cb32b08f',
#  '5a905f000fc1ff3df7ca807d57edb608863db05d',
#  '5a905f000fc1ff3df7ca807d57edb608863db05d',
#  'a58de017cbeda1763ea002fe027ed41b4ed53109',
#  'baf47ed8da24d607e50d8684cde78b923538640f',
#  '4bd88bfb25263a75bbdd467e74018f4ae570e5df',
#  '12768858f6a825452e412deb1df36d2d1d9c6791',
#  '5a905f000fc1ff3df7ca807d57edb608863db05d']

# %%
neighbor_songs=pd.DataFrame(columns=['user_id','song_id','listen_count','title','artist_name','song'])
#user_songs=pd.DataFrame(columns=['user_id','song_id','listen_count','title','artist_name','song'])    
for item in neighbors:
    neighbor_songs=neighbor_songs.append(song[song.user_id == item],ignore_index = True)
#user_songs.append(song[song.user_id =='000ebc858861aca26bac9b49f650ed424cf882fc'],ignore_index = True)
#print(len(user_songs))    
neighbor_songs=neighbor_songs.sort_values('listen_count',ascending=False)
neighbor_songs = neighbor_songs.filter(['listen_count','song'], axis=1) 
neighbor_songs= neighbor_songs.drop_duplicates(subset='song', keep="first")

result = neighbor_songs.head(10)
print("Top 10 recommended song for you ")
result
# Out:
# Top 10 recommended song for you
#      listen_count                                 song
# 748            28                  Sigur Rós - Sé Lest
# 1241           20              Octopus Project - Rorol
# 1564           19  Octopus Project - The Way Things Go
# 813            18               Sigur Ros - ný Batterý
# 317            18                 Sigur Rós - Sæglópur
# 1121           18          Foo Fighters - Over And Out
# 1216           18                Salt-N-Pepa - Push It
# 1447           17                     Sigur Rós - Gong
# 1034           17                OneRepublic - Secrets
# 636            17                  Sigur Rós - Andvari

# %%
user_songs=pd.DataFrame(columns=['user_id','song_id','listen_count','title','artist_name','song'])    
user_songs=user_songs.append(song[song.user_id =='000ebc858861aca26bac9b49f650ed424cf882fc'],ignore_index = True)
user_songs=user_songs.sort_values('listen_count',ascending=False)
user_songs
user_songs = user_songs.filter(['listen_count','song'], axis=1) 
user_songs= user_songs.drop_duplicates(subset='song', keep="first")
len(user_songs)
# Out:
# 96

# %%
#df1.where(df1.values==df2.values).notna()

x=set(neighbor_songs['song']).intersection(set(user_songs['song']))
x
# Out:
# {'Down To The Bone featuring Hil St. Soul - Smile To Shine',
#  'Future Rock - Gears',
#  "Martin O'Donnell And Michael Salvatori - Reclaimer",
#  'Michael Jackson - Thriller',
#  'Pete Rock & C.L. Smooth - They Reminisce Over You (Single Version)',
#  'The Beach Boys - Cotton Fields (The Cotton Song) (Digitally Remastered 01)'}

# %%
s=pd.DataFrame(s) 
print("most recommended songs based on popularity\n\n",s)
s
# Out:
# most recommended songs based on popularity
#
#                                                      song
# Harmonia - Sehr kosmisch                            8277
# Kings Of Leon - Use Somebody                        7952
# Björk - Undo                                        7032
# Florence + The Machine - Dog Days Are Over (Rad...  6949
# Dwight Yoakam - You're The One                      6412
# Kings Of Leon - Revelry                             6145
# OneRepublic - Secrets                               5841
# Coldplay - Yellow                                   5658
# Justin Bieber - Somebody To Love                    5546
# Barry Tuckwell/Academy of St Martin-in-the-Fiel...  5385
#                                                     song
# Harmonia - Sehr kosmisch                            8277
# Kings Of Leon - Use Somebody                        7952
# Björk - Undo                                        7032
# Florence + The Machine - Dog Days Are Over (Rad...  6949
# Dwight Yoakam - You're The One                      6412
# Kings Of Leon - Revelry                             6145
# OneRepublic - Secrets                               5841
# Coldplay - Yellow                                   5658
# Justin Bieber - Somebody To Love                    5546
# Barry Tuckwell/Academy of St Martin-in-the-Fiel...  5385

# %%
s['song'] = s['song'].apply(str)
d=s.index
print(d)
g=pd.DataFrame(data=d, columns=['song'])
print("popular songs\n\n",g)
x=set(g['song']).intersection(set(user_songs['song']))
print("user songs\n\n",user_songs)
x
# Out:
# Index(['Harmonia - Sehr kosmisch', 'Kings Of Leon - Use Somebody',
#        'Björk - Undo',
#        'Florence + The Machine - Dog Days Are Over (Radio Edit)',
#        'Dwight Yoakam - You're The One', 'Kings Of Leon - Revelry',
#        'OneRepublic - Secrets', 'Coldplay - Yellow',
#        'Justin Bieber - Somebody To Love',
#        'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner - Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'],
#       dtype='object')
# popular songs
#
#                                                  song
# 0                           Harmonia - Sehr kosmisch
# 1                       Kings Of Leon - Use Somebody
# 2                                       Björk - Undo
# 3  Florence + The Machine - Dog Days Are Over (Ra...
# 4                     Dwight Yoakam - You're The One
# 5                            Kings Of Leon - Revelry
# 6                              OneRepublic - Secrets
# 7                                  Coldplay - Yellow
# 8                   Justin Bieber - Somebody To Love
# 9  Barry Tuckwell/Academy of St Martin-in-the-Fie...
# user songs
#
#     listen_count                                               song
# 84           10                    Thelma Houston - I'm Here Again
# 83            7                          George Michael - Fastlove
# 66            5                                        Musiq - 143
# 10            5             Nick Drake - One Of These Things First
# 92            5  Crosby_ Stills & Nash - Guinnevere [Remastered...
# ..          ...                                                ...
# 33            1  John Parr - St. Elmos Fire ( Man In Motion ) (...
# 32            1    Carla Bruni - Quelqu'un M'a Dit (Album Version)
# 31            1          Earthless - Cherry Red (Groundhogs Cover)
# 30            1  Tears For Fears - Everybody Wants To Rule The ...
# 48            1                              Lionel Richie - Hello
#
# [96 rows x 2 columns]
# set()
